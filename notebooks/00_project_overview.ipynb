# %% [markdown]
# # 00 — Project Overview
#
# This notebook explains the structure of the unsupervised learning lab.
#
# The repository is designed to show more than isolated algorithms. It shows how to frame unsupervised learning problems, build features, compare assumptions, evaluate without labels, and communicate uncertainty.

# %% [markdown]
# ## Case studies
#
# 1. Customer segmentation.
# 2. Dimensionality reduction and manifold learning.
# 3. Sensor anomaly detection.
# 4. Topic modelling.
# 5. Recommender embeddings.
# 6. Model selection, stability, and explainability.

# %%
from pathlib import Path

root = Path.cwd()
print(f"Repository root: {root}")
print("Main notebooks:")
for path in sorted((root / "notebooks").glob("*.ipynb")):
    print(f"- {path.name}")

# %% [markdown]
# ## What good unsupervised learning needs
#
# Unsupervised learning does not give ground truth automatically. A strong workflow needs:
#
# - meaningful features,
# - clear assumptions,
# - comparison across model families,
# - stability analysis,
# - interpretability,
# - and humility about what the model can conclude.
